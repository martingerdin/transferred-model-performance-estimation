# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
import pickle

# %%
df_base = pd.read_csv('../data/news/base_dataset.csv')
df_transfer = pd.read_csv('../data/news/transfer_dataset.csv')

# %%
df_transfer
# Out:
#                       hospital country  resp_rate  confusion gender  death30d  \
# 0    Hôpital de la Salpêtrière  France         24          0      f         0
# 1    Hôpital de la Salpêtrière  France         28          0      m         0
# 2    Hôpital de la Salpêtrière  France         34          0      f         0
# 3    Hôpital de la Salpêtrière  France         18          0      f         0
# 4    Hôpital de la Salpêtrière  France         20          0      f         0
# ..                         ...     ...        ...        ...    ...       ...
# 350  Hôpital de la Salpêtrière  France         20          0      f         0
# 351  Hôpital de la Salpêtrière  France         23          0      m         0
# 352  Hôpital de la Salpêtrière  France         24          0      m         0
# 353  Hôpital de la Salpêtrière  France         16          0      m         0
# 354  Hôpital de la Salpêtrière  France         20          0      f         0
#
# ...

# %%
label = 'death30d'
features = [
    'resp_rate',
    'confusion',
    'SpO2',
    'BPS',
    #'BPD', # Has nulls
    'HR',
    'temp',
    #'MR-proADM', # Has nulls
    #'PCT', # Has nulls
    #'LOS', # Has nulls
    'age',
    'ICU', # Will this leak information?
]

# %%
transfer_X = df_transfer[features]
transfer_Y = df_transfer[label]

# %%
model = pickle.load(open('../models/news/lr.sav', 'rb'))
model
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = model.predict_proba(transfer_X)[:, 1]

# %%
roc_auc_score(transfer_Y, predictions)
# Out:
# 0.864122418879056
