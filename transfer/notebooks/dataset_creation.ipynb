# %%
import pandas as pd

# %%
news_data = pd.read_excel('https://datadryad.org/bitstream/handle/10255/dryad.199708/NEWS_datafile.xls?sequence=1')
news_data.to_csv('../data/news/news_data.csv', index=False)

# %%
news_data
# Out:
#                  hospital      country  resp_rate  confusion gender  death30d  \
# 0     Clearwater Hospital          USA         22          0      m         0
# 1     Clearwater Hospital          USA         20          0      m         0
# 2     Clearwater Hospital          USA         18          1      f         1
# 3     Clearwater Hospital          USA         17          0      m         0
# 4     Clearwater Hospital          USA         16          0      m         0
# ...                   ...          ...        ...        ...    ...       ...
# 1298                Aarau  Switzerland         24          0      f         0
# 1299                Aarau  Switzerland         34          0      m         0
# 1300                Aarau  Switzerland         32          0      f         0
# 1301                Aarau  Switzerland         18          0      m         0
# 1302                Aarau  Switzerland         40          0      f         0
#
# ...

# %%
news_data['country'].value_counts()
# Out:
# USA            940
# France         355
# Switzerland      8
# Name: country, dtype: int64

# %%
df_base = news_data[news_data['country'] == 'USA']
df_transfer = news_data[news_data['country'] == 'France']

# %%
df_base.to_csv('../data/news/base_dataset.csv', index=False)
df_transfer.to_csv('../data/news/transfer_dataset.csv', index=False)
